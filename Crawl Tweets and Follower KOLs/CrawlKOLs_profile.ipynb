# %% [markdown]
# # Install and import lib

# %%
# %pip install tweety-ns
# %pip install https://github.com/mahrtayyab/tweety/archive/main.zip --upgrade
# Out:
# Requirement already satisfied: tweety-ns in c:\users\admin\anaconda3\envs\caries\lib\site-packages (2.0.8)
# Requirement already satisfied: beautifulsoup4~=4.12 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4[lxml]~=4.12->tweety-ns) (4.12.2)
# Requirement already satisfied: openpyxl in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (3.1.5)
# Requirement already satisfied: httpx[http2] in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (0.28.1)
# Requirement already satisfied: dateutils in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (0.6.12)
# Requirement already satisfied: anticaptchaofficial in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (1.0.62)
# Requirement already satisfied: capsolver in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (1.0.7)
# Requirement already satisfied: 2captcha-python in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (1.5.0)
# Requirement already satisfied: python-magic in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (0.4.27)
# Requirement already satisfied: python-magic-bin in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns) (0.4.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4~=4.12->beautifulsoup4[lxml]~=4.12->tweety-ns) (2.5)
# Requirement already satisfied: lxml in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4[lxml]~=4.12->tweety-ns) (5.3.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from 2captcha-python->tweety-ns) (2.31.0)
# Requirement already satisfied: py>=1.4.32 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from anticaptchaofficial->tweety-ns) (1.11.0)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from dateutils->tweety-ns) (2.8.2)
# Requirement already satisfied: pytz in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from dateutils->tweety-ns) (2023.3.post1)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns) (4.2.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns) (1.0.7)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns) (3.4)
# Requirement already satisfied: h2<5,>=3 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpcore==1.*->httpx[http2]->tweety-ns) (0.14.0)
# Requirement already satisfied: et-xmlfile in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from openpyxl->tweety-ns) (2.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from h2<5,>=3->httpx[http2]->tweety-ns) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from h2<5,>=3->httpx[http2]->tweety-ns) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from requests->2captcha-python->tweety-ns) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from requests->2captcha-python->tweety-ns) (2.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from anyio->httpx[http2]->tweety-ns) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from python-dateutil->dateutils->tweety-ns) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting https://github.com/mahrtayyab/tweety/archive/main.zip
#   Using cached https://github.com/mahrtayyab/tweety/archive/main.zip
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4~=4.12 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4[lxml]~=4.12->tweety-ns==2.0.8) (4.12.2)
# Requirement already satisfied: openpyxl in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (3.1.5)
# Requirement already satisfied: httpx[http2] in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (0.28.1)
# Requirement already satisfied: dateutils in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (0.6.12)
# Requirement already satisfied: anticaptchaofficial in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (1.0.62)
# Requirement already satisfied: capsolver in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (1.0.7)
# Requirement already satisfied: 2captcha-python in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (1.5.0)
# Requirement already satisfied: python-magic in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (0.4.27)
# Requirement already satisfied: python-magic-bin in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from tweety-ns==2.0.8) (0.4.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4~=4.12->beautifulsoup4[lxml]~=4.12->tweety-ns==2.0.8) (2.5)
# Requirement already satisfied: lxml in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from beautifulsoup4[lxml]~=4.12->tweety-ns==2.0.8) (5.3.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from 2captcha-python->tweety-ns==2.0.8) (2.31.0)
# Requirement already satisfied: py>=1.4.32 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from anticaptchaofficial->tweety-ns==2.0.8) (1.11.0)
# Requirement already satisfied: python-dateutil in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from dateutils->tweety-ns==2.0.8) (2.8.2)
# Requirement already satisfied: pytz in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from dateutils->tweety-ns==2.0.8) (2023.3.post1)
# Requirement already satisfied: anyio in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns==2.0.8) (4.2.0)
# Requirement already satisfied: certifi in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns==2.0.8) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns==2.0.8) (1.0.7)
# Requirement already satisfied: idna in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns==2.0.8) (3.4)
# Requirement already satisfied: h2<5,>=3 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpx[http2]->tweety-ns==2.0.8) (4.1.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from httpcore==1.*->httpx[http2]->tweety-ns==2.0.8) (0.14.0)
# Requirement already satisfied: et-xmlfile in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from openpyxl->tweety-ns==2.0.8) (2.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from h2<5,>=3->httpx[http2]->tweety-ns==2.0.8) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from h2<5,>=3->httpx[http2]->tweety-ns==2.0.8) (4.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from requests->2captcha-python->tweety-ns==2.0.8) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from requests->2captcha-python->tweety-ns==2.0.8) (2.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from anyio->httpx[http2]->tweety-ns==2.0.8) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\envs\caries\lib\site-packages (from python-dateutil->dateutils->tweety-ns==2.0.8) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tweety import Twitter
import asyncio
import os
import csv
import tweety
import time

# %% [markdown]
# # Login

# %%
auth_token = os.getenv("auth_token1")

# Cookies can be a str or a dict

app = Twitter("session")
app.load_auth_token(auth_token)
# Out:
# <coroutine object AuthMethods.load_auth_token at 0x0000027FF367BBC0>

# %%
async def login():
    # Read username and password from environment variables
    username = "ntluongg"
    password = "Dung0212"

    if not username or not password:
        raise ValueError("USERNAMEE or PASSWORD is not configured in the .env file")

    # Initialize Twitter client
    app = Twitter("session")
    await app.sign_in(username, password)
    return app

# %%
app = await login()

# %% [markdown]
# # Crawl tweet

# %%
async def crawl_tweets_from_KOLs(input_file_path, output_file_path, app, pages=1, replies=False, wait_time=2, cursor=None):
    tweets_data = []

    # Read the input file and get the list of screen names
    with open(input_file_path, mode='r', newline='', encoding='utf-8') as infile:
        reader = csv.DictReader(infile)
        screen_names = [row['screen_name'] for row in reader]
        screen_names = screen_names[70:140] #thay số chỗ nà

    # Open the error file to log users with rate limit errors
    with open("crawl_user_tweets_error.txt", mode="a", encoding="utf-8") as error_file:
        # Loop through each screen name to fetch tweets
        for screen_name in screen_names:
            print(f"Fetching tweets for user: {screen_name}")
            count = 0
            while True :
                if count > 3: 
                    print(f'skip {screen_name}')
                    break
                try:
                    all_tweets = await app.get_tweets(
                        username=screen_name,
                        pages=pages,
                        replies=replies,
                        wait_time=wait_time,
                        cursor=cursor
                    )
                    for tweet in all_tweets:
                        crawl = 0
                        try :
                            if type(tweet) == tweety.types.twDataTypes.Tweet:
                                crawl +=1
                                tweets_data.append({
                                    'id': tweet.id,
                                    'created_on': tweet.created_on,
                                    'date': tweet.date,
                                    'text': tweet.text,
                                    'rich_text': tweet.rich_text.text if tweet.rich_text else None,
                                    'author': tweet.author.username if tweet.author else None,
                                    'is_retweet': tweet.is_retweet,
                                    'retweeted_tweet_id': tweet.retweeted_tweet.id if tweet.is_retweet else None,
                                    'is_quoted': tweet.is_quoted,
                                    'quoted_tweet_id': tweet.quoted_tweet.id if tweet.is_quoted else None,
                                    'is_reply': tweet.is_reply,
                                    'replied_to': tweet.replied_to.id if tweet.is_reply else None,
                                    'is_sensitive': tweet.is_sensitive,
                                    'reply_counts': tweet.reply_counts,
                                    'quote_counts': tweet.quote_counts,
                                    'bookmark_count': tweet.bookmark_count,
                                    'views': tweet.views,
                                    'likes': tweet.likes,
                                    'language': tweet.language,
                                    'place': tweet.place.name if tweet.place else None,
                                    'retweet_counts': tweet.retweet_counts,
                                    'source': tweet.source,
                                    'has_moderated_replies': tweet.has_moderated_replies,
                                    'is_liked': tweet.is_liked,
                                    'is_retweeted': tweet.is_retweeted,
                                    'can_reply': tweet.can_reply,
                                    'broadcast': tweet.broadcast.title if tweet.broadcast else None,
                                    'edit_control': tweet.edit_control,
                                    'has_newer_version': tweet.has_newer_version,
                                    'audio_space_id': tweet.audio_space_id,
                                    'pool': tweet.pool.title if tweet.pool else None,
                                    'community': tweet.community.name if tweet.community else None,
                                    'media': [media.url for media in tweet.media],
                                    'user_mentions': [mention.username for mention in tweet.user_mentions],
                                    'urls': [url.url for url in tweet.urls],
                                    'hashtags': [hashtag.text for hashtag in tweet.hashtags],
                                    'symbols': [symbol.text for symbol in tweet.symbols],
                                    'community_note': tweet.community_note,
                                    'url': tweet.url,
                                    'threads': [thread.id for thread in tweet.threads],
                                    'comments': [comment.id for comment in tweet.comments]
                                })
                            elif type(tweet) == tweety.types.twDataTypes.SelfThread :
                                for sub_tweet in tweet.tweets :
                                    crawl +=1
                                    tweets_data.append({
                                'id': sub_tweet.id,
                                'created_on': sub_tweet.created_on,
                                'date': sub_tweet.date,
                                'text': sub_tweet.text,
                                'rich_text': sub_tweet.rich_text.text if sub_tweet.rich_text else None,
                                'author': sub_tweet.author.username if sub_tweet.author else None,
                                'is_retweet': sub_tweet.is_retweet,
                                'retweeted_tweet_id': sub_tweet.retweeted_tweet.id if sub_tweet.is_retweet else None,
                                'is_quoted': sub_tweet.is_quoted,
                                'quoted_tweet_id': sub_tweet.quoted_tweet.id if sub_tweet.is_quoted else None,
                                'is_reply': sub_tweet.is_reply,
                                'replied_to': sub_tweet.replied_to.id if sub_tweet.is_reply else None,
                                'is_sensitive': sub_tweet.is_sensitive,
                                'reply_counts': sub_tweet.reply_counts,
                                'quote_counts': sub_tweet.quote_counts,
                                'bookmark_count': sub_tweet.bookmark_count,
                                'views': sub_tweet.views,
                                'likes': sub_tweet.likes,
                                'language': sub_tweet.language,
                                'place': sub_tweet.place.name if sub_tweet.place else None,
                                'retweet_counts': sub_tweet.retweet_counts,
                                'source': sub_tweet.source,
                                'has_moderated_replies': sub_tweet.has_moderated_replies,
                                'is_liked': sub_tweet.is_liked,
                                'is_retweeted': sub_tweet.is_retweeted,
                                'can_reply': sub_tweet.can_reply,
                                'broadcast': sub_tweet.broadcast.title if sub_tweet.broadcast else None,
                                'edit_control': sub_tweet.edit_control,
                                'has_newer_version': sub_tweet.has_newer_version,
                                'audio_space_id': sub_tweet.audio_space_id,
                                'pool': sub_tweet.pool.title if sub_tweet.pool else None,
                                'community': sub_tweet.community.name if sub_tweet.community else None,
                                'media': [media.url for media in sub_tweet.media],
                                'user_mentions': [mention.username for mention in sub_tweet.user_mentions],
                                'urls': [url.url for url in sub_tweet.urls],
                                'hashtags': [hashtag.text for hashtag in sub_tweet.hashtags],
                                'symbols': [symbol.text for symbol in sub_tweet.symbols],
                                'community_note': sub_tweet.community_note,
                                'url': sub_tweet.url,
                                'threads': [thread.id for thread in sub_tweet.threads],
                                'comments': [comment.id for comment in sub_tweet.comments]
                            })
                        except : 
                            print('skip tweet')
                        print(f"Successfully fetched {crawl} tweets for {tweet}.")
                    break
                except Exception as e:
                    print(f"Error fetching tweets for user {screen_name}: {e}")
                    count += 1
                    time.sleep(300) #retry after 60 seconds

        # Check if the output file exists
        file_exists = os.path.isfile(output_file_path)

        # Save the results to the CSV file (append if the file exists, otherwise write header)
        with open(output_file_path, mode='a' if file_exists else 'w', newline='', encoding='utf-8') as outfile:
            fieldnames = [
                'id', 'created_on', 'date', 'text', 'rich_text', 'author', 'is_retweet', 'retweeted_tweet_id',
                'is_quoted', 'quoted_tweet_id', 'is_reply', 'replied_to', 'is_sensitive', 'reply_counts',
                'quote_counts', 'bookmark_count', 'views', 'likes', 'language', 'place', 'retweet_counts',
                'source', 'has_moderated_replies', 'is_liked', 'is_retweeted', 'can_reply', 'broadcast',
                'edit_control', 'has_newer_version', 'audio_space_id', 'pool', 'community', 'media', 
                'user_mentions', 'urls', 'hashtags', 'symbols', 'community_note', 'url', 'threads', 'comments'
            ]
            writer = csv.DictWriter(outfile, fieldnames=fieldnames)

            # Write header only if the file does not exist
            if not file_exists:
                writer.writeheader()

            writer.writerows(tweets_data)

        print(f"Saved {len(tweets_data)} tweets to {output_file_path}.")

# %%
# # Basic Tweet Information
# 'id': int                # The unique ID of the tweet (assigned by Twitter).
# 'created_on': datetime   # The date and time when the tweet was created.
# 'date': datetime         # The date and time when the tweet was created (same as created_on).

# # Main Content of the Tweet
# 'text': str              # The text content of the tweet (original text).
# 'rich_text': RichText    # The rich text content (if any), which may include HTML formatting or other styles.
# 'author': User           # The user object containing information about the tweet's author (e.g., username, ID, etc.).

# # Tweet Interaction (Retweets, Quotes, Replies)
# 'is_retweet': bool              # If `True`, the tweet is a retweet of another tweet.
# 'retweeted_tweet_id': int       # The ID of the original tweet that was retweeted (if applicable).
# 'is_quoted': bool               # If `True`, the tweet is a quoted tweet.
# 'quoted_tweet_id': int          # The ID of the tweet that was quoted (if applicable).
# 'is_reply': bool                # If `True`, the tweet is a reply to another tweet.
# 'replied_to': Tweet | str       # The tweet being replied to (if applicable), or the user ID if it is a reply to a user.

# # Sensitive Content Information
# 'is_sensitive': bool            # If `True`, the tweet contains sensitive content (e.g., graphic images, NSFW).

# # Engagement Metrics
# 'reply_counts': int            # The number of times someone has replied to this tweet.
# 'quote_counts': int            # The number of times this tweet has been quoted.
# 'bookmark_count': int          # The number of times this tweet has been bookmarked.
# 'views': int                   # The number of times this tweet has been viewed.
# 'likes': int                   # The number of likes (favorites) this tweet has received.
# 'language': str                # The language of the tweet as identified by Twitter (e.g., 'en' for English).
# 'place': Place                 # The location or place associated with the tweet, if available.

# # Retweet Information
# 'retweet_counts': int          # The number of times this tweet has been retweeted.

# # Source and Moderation Information
# 'source': str                  # The source application used to post the tweet (e.g., "Twitter Web App").
# 'has_moderated_replies': bool  # If `True`, replies to the tweet are moderated by the author.

# # User Interaction Information
# 'is_liked': bool               # If `True`, the authenticated user has liked this tweet.
# 'is_retweeted': bool           # If `True`, the authenticated user has retweeted this tweet.
# 'can_reply': bool              # If `True`, the authenticated user is allowed to reply to this tweet.

# # Broadcast and Edit Information
# 'broadcast': Broadcast | None  # Information about the broadcast (if the tweet is part of a broadcast).
# 'edit_control': EditControl | None  # Information about the tweet's edit control (if it has been edited).
# 'has_newer_version': bool      # If `True`, this tweet has been edited, and there is a newer version of it.

# # Additional Tweet Metadata
# 'audio_space_id': str          # The ID of the Audio Space associated with the tweet (if applicable).
# 'pool': Pool | None            # The pool associated with the tweet (if applicable).
# 'community': Community | None  # The community this tweet is a part of (if applicable).

# # Media and Mentions
# 'media': list[Media]          # A list of media objects (e.g., images, videos) attached to the tweet.
# 'user_mentions': list[ShortUser]  # A list of users mentioned in the tweet.
# 'urls': list[URL]             # A list of URLs mentioned in the tweet.
# 'hashtags': list[Hashtag]      # A list of hashtags mentioned in the tweet.
# 'symbols': list[Symbol]       # A list of symbols (e.g., stock symbols) mentioned in the tweet.

# # Community and Thread Information
# 'community_note': str | None   # A community note posted in response to the tweet (if applicable).
# 'url': str                     # The URL of the tweet.
# 'threads': list[Tweet]         # A list of tweets in the thread of this tweet.
# 'comments': list[ConversationThread]  # A list of replies or comments sent in response to this tweet.

# %%
input_file_path = "cleanedd_KOL_profile_status_count_more_than_200.csv"
output_file_path ="final_tweet.csv"
await crawl_tweets_from_KOLs(input_file_path, output_file_path, app, pages=10, replies=False, wait_time=10, cursor=None)
# Out:
# Fetching tweets for user: DownsandTowns
# Successfully fetched 1 tweets for Tweet(id=1866334025042088078, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-10 04:08:01+00:00).
# Successfully fetched 1 tweets for Tweet(id=1866153149393780976, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-09 16:09:16+00:00).
# Successfully fetched 1 tweets for Tweet(id=1866148829155770657, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-09 15:52:06+00:00).
# Successfully fetched 1 tweets for Tweet(id=1866148733500747846, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-09 15:51:44+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865608748644884955, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-08 04:06:01+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865405043765031235, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-07 14:36:34+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865233890559811938, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-07 03:16:28+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865063991438970915, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-06 16:01:21+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865060558203912338, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-06 15:47:42+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865041979580498349, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-06 14:33:53+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865040705237688762, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-06 14:28:49+00:00).
# Successfully fetched 1 tweets for Tweet(id=1865040411355476198, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-06 14:27:39+00:00).
# Successfully fetched 1 tweets for Tweet(id=1864539059982303372, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-05 05:15:28+00:00).
# Successfully fetched 1 tweets for Tweet(id=1864348380727554108, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-04 16:37:46+00:00).
# Successfully fetched 1 tweets for Tweet(id=1864075807515185380, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-03 22:34:40+00:00).
# skip tweet
# Successfully fetched 2 tweets for SelfThread(tweets=2, all_tweets=2).
# skip tweet
# Successfully fetched 1 tweets for SelfThread(tweets=1, all_tweets=2).
# Successfully fetched 1 tweets for Tweet(id=1863716787386245274, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-02 22:48:02+00:00).
# Successfully fetched 1 tweets for Tweet(id=1863707313258872959, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-02 22:10:24+00:00).
# Successfully fetched 1 tweets for Tweet(id=1863590937944813795, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-02 14:27:58+00:00).
# Successfully fetched 1 tweets for Tweet(id=1863227830865162740, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-12-01 14:25:06+00:00).
# Successfully fetched 1 tweets for Tweet(id=1862281733158174946, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-28 23:45:39+00:00).
# Successfully fetched 1 tweets for Tweet(id=1861811414345584979, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-27 16:36:46+00:00).
# Successfully fetched 1 tweets for Tweet(id=1861811364156653692, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-27 16:36:34+00:00).
# Successfully fetched 1 tweets for Tweet(id=1861811321580269847, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-27 16:36:24+00:00).
# skip tweet
# Successfully fetched 2 tweets for SelfThread(tweets=2, all_tweets=2).
# skip tweet
# Successfully fetched 2 tweets for SelfThread(tweets=3, all_tweets=4).
# Successfully fetched 1 tweets for Tweet(id=1861041335425249418, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-25 13:36:45+00:00).
# Successfully fetched 1 tweets for Tweet(id=1860418652777988226, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-23 20:22:26+00:00).
# Successfully fetched 1 tweets for Tweet(id=1860361814476824956, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-23 16:36:35+00:00).
# Successfully fetched 1 tweets for Tweet(id=1860349666220458442, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-23 15:48:18+00:00).
# Successfully fetched 1 tweets for Tweet(id=1859438937380471190, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-21 03:29:24+00:00).
# Successfully fetched 1 tweets for Tweet(id=1858651202637996121, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-18 23:19:13+00:00).
# Successfully fetched 1 tweets for Tweet(id=1858564034745765974, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-18 17:32:50+00:00).
# Successfully fetched 1 tweets for Tweet(id=1858507498111770916, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-18 13:48:11+00:00).
# Successfully fetched 1 tweets for Tweet(id=1858506101203103817, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-18 13:42:38+00:00).
# Successfully fetched 1 tweets for Tweet(id=1858199516325057013, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-17 17:24:23+00:00).
# Successfully fetched 1 tweets for Tweet(id=1857827101711413635, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-16 16:44:32+00:00).
# Successfully fetched 1 tweets for Tweet(id=1857301109490307204, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-15 05:54:26+00:00).
# Successfully fetched 1 tweets for Tweet(id=1857088401368891842, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-14 15:49:12+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856960848503140697, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-14 07:22:21+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856927763199939001, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-14 05:10:53+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856753760191807784, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-13 17:39:27+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856389431575621918, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-12 17:31:45+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856382681183031352, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-12 17:04:55+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856259586430587003, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-12 08:55:47+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856074653799985252, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-11 20:40:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856060492508438993, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-11 19:44:40+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856028961442279689, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-11 17:39:22+00:00).
# Successfully fetched 1 tweets for Tweet(id=1856009848204439777, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-11 16:23:25+00:00).
# Successfully fetched 1 tweets for Tweet(id=1855876590019981655, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-11 07:33:54+00:00).
# Successfully fetched 1 tweets for Tweet(id=1855411594198659161, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-10 00:46:10+00:00).
# Successfully fetched 1 tweets for Tweet(id=1854979185300877372, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-08 20:07:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1854780952268226971, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-08 07:00:13+00:00).
# skip tweet
# Successfully fetched 2 tweets for SelfThread(tweets=2, all_tweets=2).
# Successfully fetched 1 tweets for Tweet(id=1854327139581173811, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-07 00:56:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1853844973411815496, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-05 17:00:59+00:00).
# Successfully fetched 1 tweets for Tweet(id=1853621237366260059, author=User(id=368602339, username=DownsandTowns, name=Downs & Towns 📷, verified=True), created_on=2024-11-05 02:11:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1
author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:44:44+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923563829579777, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:44:23+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923534226132997, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:44:16+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923375220264960, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:43:38+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923296878804994, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:43:19+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923257825886211, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:43:10+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923201999454209, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:42:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923160794882048, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:42:47+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923069983735808, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:42:25+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609923040216768517, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:42:18+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609922645457514496, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:40:44+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609922378095824898, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:39:40+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609922208088096768, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:38:59+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609922154140766211, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:38:47+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609922086570688512, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 14:38:31+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609882568509341705, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 12:01:29+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609882109564407810, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:59:39+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609881489218453506, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:57:11+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609880936149123072, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:54:59+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609880028678086656, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:51:23+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609879209043804161, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:48:08+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609877021928181761, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:39:26+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609876002590674951, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:35:23+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609875049032318976, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:31:36+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609874500614602754, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:29:25+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609874099895144452, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 11:27:50+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842641507651584, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:22:49+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842524113309696, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:22:21+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842337915736064, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:21:37+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842302960259075, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:21:29+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842246114852865, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:21:15+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609842201965592577, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:21:05+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841913783324673, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:19:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841866886856704, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:19:45+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841836549365763, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:19:37+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841804806856710, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:19:30+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841761714667520, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:19:20+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841671381950464, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:18:58+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841564003749888, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:18:32+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841530910478336, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:18:25+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841476795498502, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:18:12+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841359258533888, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:17:44+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841334327582720, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:17:38+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841204576788480, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:17:07+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609841177775280129, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:17:00+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609840930919530497, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:16:01+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609840819002810368, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:15:35+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609840762958626816, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:15:21+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609840729802563587, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:15:14+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609840634294140928, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:14:51+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609839945195175936, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:12:06+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609839273687109632, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:09:26+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609838760895696902, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:07:24+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609838025088933888, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:04:29+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609837134029922304, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 09:00:56+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609836587482767362, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 08:58:46+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609834792983429131, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 08:51:38+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609833827702276096, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 08:47:48+00:00).
# Successfully fetched 1 tweets for Tweet(id=1609829461414780928, author=User(id=4478796257, username=Nollymaster, name=DE_MASTER |@MoonAppXXX🌔, verified=False), created_on=2023-01-02 08:30:27+00:00).
# Saved 12179 tweets to final_tweet.csv.

# %%
# Read keywords from a text file
def read_keywords_from_file(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        return [line.strip() for line in file if line.strip()]
# Danh sách các giá trị trong cột 'b' mà bạn muốn xóa
X = read_keywords_from_file("loc.txt")
print(X)
# Out:
# ['1281273004341841923', '1498984512', '20486941', '1064986661723922432', '1264467031384088581', '1487057201328009219', '1159451278008901632', '1496174374075916294', '1563771264', '1303420675114201089', '1453573933815369731', '1431050544685088768', '885490321550868480', '1248332026790330369', '1619659433952546817', '1462451461728587780', '1301509419696558082', '791786474', '1392088851221413893', '1457015038691057666', '1416665472469135365', '1376655684872200192', '43358536', '262165644', '857031238569181184', '69777546', '1384010537328025602', '1716071804853268481', '1353693148321624066', '2438767100', '263689859', '1545599597036605440', '2310943632', '23942310', '70355577', '1530371', '812505876754038784', '1416471276831469569', '851104049722122240', '961335348474281987', '944510856712224770', '67197023', '1455391184411496458', '2370753746', '9897812', '857729198198095873', '14196323', '45360564', '17225803', '1326397615202820096', '1478555106652086280', '197034892', '48036658', '1053941412113321984', '1428184265741635586', '872380984775380992', '17819472', '1291222903552319488', '1396351268109619202', '1546677190280024065', '1565716651118854145', '1123705505510248448', '1327720803044093955']

# %%
import pandas as pd
df = pd.read_csv("cleanedd_KOL_profile_status_count_more_than_200.csv")
df_cleaned = df[~df['id'].isin(X)]
print(df['id'].dtype)
# Out:
# int64
