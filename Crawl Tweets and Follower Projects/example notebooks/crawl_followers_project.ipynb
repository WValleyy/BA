# %% [markdown]
# # Install and import lib

# %%
from tweety import Twitter
import asyncio
import os
import csv
import tweety
import time

# %% [markdown]
# # Login

# %%
auth_token = os.getenv("auth_token1")

# Cookies can be a str or a dict

app = Twitter("session")
app.load_auth_token(auth_token)
# Out:
# <coroutine object AuthMethods.load_auth_token at 0x00000228400BBDE0>

# %%
async def login():
    # Read username and password from environment variables
    username = ""
    password = ""

    if not username or not password:
        raise ValueError("USERNAMEE or PASSWORD is not configured in the .env file")

    # Initialize Twitter client
    app = Twitter("session")
    await app.sign_in(username, password)
    return app

# %%
app = await login()

# %%
from tweety.types import twDataTypes

async def crawl_followers_usernames(input_file_path, output_file_path, app, pages=1, wait_time=2):
    kol_followers_data = []

    # Read the input file and get the list of screen names
    with open(input_file_path, mode='r', newline='', encoding='utf-8') as infile:
        reader = csv.DictReader(infile)
        screen_names = [row['twitter_id'] for row in reader]
        screen_names = screen_names[:500] #thay số chỗ nà
    
    # Open the error file to log users with rate limit errors
    with open("crawl_user_followers_error.txt", mode="a", encoding="utf-8") as error_file:
        # Loop through each KOL username to fetch their followers
        for screen_name in screen_names:
            print(f"Fetching followers for user: {screen_name}")
            retry_count = 0
            while retry_count <= 3:  # Retry up to 3 times
                try:
                    # Fetch followers using the Tweety app
                    all_followers = await app.get_user_followers(
                        username=screen_name,
                        pages=pages,
                        wait_time=wait_time
                    )
                    # Collect only the follower usernames
                    followers_usernames = [follower.username for follower in all_followers]
                    kol_followers_data.append({
                        'KOL_username': screen_name,
                        'followers_usernames': followers_usernames
                    })
                    break  # Exit retry loop if successful
                except Exception as e:
                    retry_count += 1
                    print(f"Error fetching followers for user {screen_name}: {e}. Retrying ({retry_count}/3)...")
                    if retry_count > 3:
                        error_file.write(f"{screen_name}\n")
                    time.sleep(300)  # Wait before retrying

    # Save the results to the output file in a structured format
    with open(output_file_path, mode='w', newline='', encoding='utf-8') as outfile:
        writer = csv.writer(outfile)
        writer.writerow(['KOL_username', 'followers_usernames'])  # Write the header

        for data in kol_followers_data:
            writer.writerow([data['KOL_username'], ', '.join(map(str, data['followers_usernames']))])

    print(f"Saved followers for {len(kol_followers_data)} KOLs to {output_file_path}.")

# %%
import csv
import time
from tweety.types import twDataTypes

async def crawl_followers_usernames(input_file_path, output_file_path, app, pages=1, wait_time=2):
    # Đọc danh sách screen_name từ file đầu vào
    with open(input_file_path, mode='r', newline='', encoding='utf-8') as infile:
        reader = csv.DictReader(infile)
        screen_names = [row['twitter_id'] for row in reader]
        screen_names = screen_names[500:1000] #thay số chỗ nà
    # Mở file lỗi để ghi log những user gặp lỗi
    with open("crawl_user_followers_error.txt", mode="a", encoding="utf-8") as error_file, \
         open(output_file_path, mode='a', newline='', encoding='utf-8') as outfile:
        writer = csv.writer(outfile)
        
        # Ghi header vào file đầu ra (nếu file rỗng)
        if outfile.tell() == 0:  # Chỉ ghi header nếu file chưa có nội dung
            writer.writerow(['KOL_username', 'followers_usernames'])

        # Lặp qua từng KOL username để fetch followers
        for screen_name in screen_names:
            print(f"Fetching followers for user: {screen_name}")
            retry_count = 0

            while retry_count <= 3:  # Thử lại tối đa 3 lần
                try:
                    # Fetch followers bằng app Tweety
                    all_followers = await app.get_user_followers(
                        username=screen_name,
                        pages=pages,
                        wait_time=wait_time
                    )
                    
                    # Lấy danh sách username của followers
                    followers_usernames = [follower.username for follower in all_followers]
                    
                    # Lưu dữ liệu của user vừa crawl được vào file
                    writer.writerow([screen_name, ', '.join(map(str, followers_usernames))])
                    print(f"Saved followers for user: {screen_name}")
                    break  # Thoát khỏi vòng lặp retry nếu thành công
                except Exception as e:
                    retry_count += 1
                    print(f"Error fetching followers for user {screen_name}: {e}. Retrying ({retry_count}/3)...")
                    if retry_count > 3:
                        error_file.write(f"{screen_name}\n")
                    time.sleep(300)  # Chờ trước khi thử lại

# %%
input_file_path = "twitter_ids.csv"
output_file_path ="project_test_followers.csv"
await crawl_followers_usernames(input_file_path, output_file_path, app, pages=10, wait_time=10)
# Out:
# Fetching followers for user: KalmyAPP
# Saved followers for user: KalmyAPP
# Fetching followers for user: raft_fi
# Saved followers for user: raft_fi
# Fetching followers for user: gnosisPM
# Saved followers for user: gnosisPM
# Fetching followers for user: TheTNetwork
# Saved followers for user: TheTNetwork
# Fetching followers for user: parsiq_net
# Saved followers for user: parsiq_net
# Fetching followers for user: AcrossProtocol
# Error fetching followers for user AcrossProtocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user AcrossProtocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: AcrossProtocol
# Fetching followers for user: HorizonProtocol
# Saved followers for user: HorizonProtocol
# Fetching followers for user: DomaniProtocol
# Saved followers for user: DomaniProtocol
# Fetching followers for user: CUDOS_
# Saved followers for user: CUDOS_
# Fetching followers for user: BuildOnLumia
# Saved followers for user: BuildOnLumia
# Fetching followers for user: arbitrum
# Error fetching followers for user arbitrum: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user arbitrum: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: arbitrum
# Fetching followers for user: ShidoGlobal
# Saved followers for user: ShidoGlobal
# Fetching followers for user: Multibit_Bridge
# Saved followers for user: Multibit_Bridge
# Fetching followers for user: CryptoAlgebra
# Saved followers for user: CryptoAlgebra
# Fetching followers for user: k9finance
# Saved followers for user: k9finance
# Fetching followers for user: Kommunitas1
# Error fetching followers for user Kommunitas1: User is suspended. Retrying (1/3)...
# Error fetching followers for user Kommunitas1: User is suspended. Retrying (2/3)...
# Error fetching followers for user Kommunitas1: User is suspended. Retrying (3/3)...
# Error fetching followers for user Kommunitas1: User is suspended. Retrying (4/3)...
# Fetching followers for user: Team3D_Official
# Saved followers for user: Team3D_Official
# Fetching followers for user: _pacmanfinance
# Saved followers for user: _pacmanfinance
# Fetching followers for user: fasttoken_com
# Saved followers for user: fasttoken_com
# Fetching followers for user: aelfblockchain
# Saved followers for user: aelfblockchain
# Fetching followers for user: xwg_games
# Saved followers for user: xwg_games
# Fetching followers for user: HoudiniSwap
# Error fetching followers for user HoudiniSwap: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user HoudiniSwap: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: HoudiniSwap
# Fetching followers for user: FinanceChainge
# Saved followers for user: FinanceChainge
# Fetching followers for user: WAX_io
# Saved followers for user: WAX_io
# Fetching followers for user: nftbmarket
# Saved followers for user: nftbmarket
# Fetching followers for user: neptunemutual
# Saved followers for user: neptunemutual
# Fetching followers for user: Oxygen_protocol
# Error fetching followers for user Oxygen_protocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Oxygen_protocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Oxygen_protocol
# Fetching followers for user: VaultCraft_io
# Saved followers for user: VaultCraft_io
# Fetching followers for user: RadioShack
# Saved followers for user: RadioShack
# Fetching followers for user: tokenfi
# Saved followers for user: tokenfi
# Fetching followers for user: goneuralai
# Saved followers for user: goneuralai
# Fetching followers for user: xyfinance
# Error fetching followers for user xyfinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user xyfinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: xyfinance
# Fetching followers for user: tutellus
# Saved followers for user: tutellus
# Fetching followers for user: unizen_io
# Saved followers for user: unizen_io
# Fetching followers for user: yieldyak_
# Saved followers for user: yieldyak_
# Fetching followers for user: Hector_Network
# Saved followers for user: Hector_Network
# Fetching followers for user: kineprotocol
# Error fetching followers for user kineprotocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user kineprotocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: kineprotocol
# Fetching followers for user: yai_erc
# Saved followers for user: yai_erc
# Fetching followers for user: Mozaic_Fi
# Saved followers for user: Mozaic_Fi
# Fetching followers for user: _dedprz
# Saved followers for user: _dedprz
# Fetching followers for user: _dedprz
# Saved followers for user: _dedprz
# Fetching followers for user: EmpyrealArb
# Saved followers for user: EmpyrealArb
# Fetching followers for user: eqifi_finance
# Error fetching followers for user eqifi_finance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user eqifi_finance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: eqifi_finance
# Fetching followers for user: geojamofficial
# Saved followers for user: geojamofficial
# Fetching followers for user: planet_finance
# Saved followers for user: planet_finance
# Fetching followers for user: holographxyz
# Saved followers for user: holographxyz
# Fetching followers for user: ApertureFinance
# Saved followers for user: ApertureFinance
# Fetching followers for user: Nuritopia
# Error fetching followers for user Nuritopia: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Nuritopia: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Nuritopia
# Fetching followers for user: HashAi_Eth
# Error fetching followers for user HashAi_Eth: User is suspended. Retrying (1/3)...
# Error fetching followers for user HashAi_Eth: User is suspended. Retrying (2/3)...
# Error fetching followers for user HashAi_Eth: User is suspended. Retrying (3/3)...
# Error fetching followers for user HashAi_Eth: User is suspended. Retrying (4/3)...
# Fetching followers for user: WeSendit
# Saved followers for user: WeSendit
# Fetching followers for user: 5ireChain
# Saved followers for user: 5ireChain
# Fetching followers for user: sora_xor
# Saved followers for user: sora_xor
# Fetching followers for user: CrowdSwap_App
# Saved followers for user: CrowdSwap_App
# Fetching followers for user: catextoken
# Saved followers for user: catextoken
# Fetching followers for user: Kryptonite_fi
# Error fetching followers for user Kryptonite_fi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Kryptonite_fi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Kryptonite_fi
# Fetching followers for user: FootballAlphaV
# Saved followers for user: FootballAlphaV
# Fetching followers for user: WhiteheartDeFi
# Saved followers for user: WhiteheartDeFi
# Fetching followers for user: Landshareio
# Saved followers for user: Landshareio
# Fetching followers for user: mevdotio
# Saved followers for user: mevdotio
# Fetching followers for user: landxfinance
# Error fetching followers for user landxfinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user landxfinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: landxfinance
# Fetching followers for user: airdao_io
# Saved followers for user: airdao_io
# Fetching followers for user: hotcrosscom
# Saved followers for user: hotcrosscom
# Fetching followers for user: restakefi
# Saved followers for user: restakefi
# Fetching followers for user: apeblock
# Saved followers for user: apeblock
# Fetching followers for user: monprotocol
# Error fetching followers for user monprotocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user monprotocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: monprotocol
# Fetching followers for user: WESET_io
# Saved followers for user: WESET_io
# Fetching followers for user: SeamlessFi
# Saved followers for user: SeamlessFi
# Fetching followers for user: AmuletProtocol
# Saved followers for user: AmuletProtocol
# Fetching followers for user: nostrafinance
# Saved followers for user: nostrafinance
# Fetching followers for user: CadenceProtocol
# Error fetching followers for user CadenceProtocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user CadenceProtocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: CadenceProtocol
# Fetching followers for user: CadenceProtocol
# Saved followers for user: CadenceProtocol
# Fetching followers for user: whyanelephant
# Saved followers for user: whyanelephant
# Fetching followers for user: tronfoundation
# Saved followers for user: tronfoundation
# Fetching followers for user: BELT_Finance
# Saved followers for user: BELT_Finance
# Fetching followers for user: PERIfinance
# Saved followers for user: PERIfinance
# Fetching followers for user: YamatoProtocol
# Error fetching followers for user YamatoProtocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user YamatoProtocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: YamatoProtocol
# Fetching followers for user: ArivaCoin
# Saved followers for user: ArivaCoin
# Fetching followers for user: Mumu_coin
# Saved followers for user: Mumu_coin
# Fetching followers for user: HelloTelos
# Saved followers for user: HelloTelos
# Fetching followers for user: sensi_fi
# Saved followers for user: sensi_fi
# Fetching followers for user: ethena_labs
# Error fetching followers for user ethena_labs: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ethena_labs: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ethena_labs
# Fetching followers for user: PEAKDEFI
# Saved followers for user: PEAKDEFI
# Fetching followers for user: safe
# Saved followers for user: safe
# Fetching followers for user: azuroprotocol
# Saved followers for user: azuroprotocol
# Fetching followers for user: StargazeZone
# Saved followers for user: StargazeZone
# Fetching followers for user: EquationDAO
# Error fetching followers for user EquationDAO: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user EquationDAO: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: EquationDAO
# Fetching followers for user: BrnMetaverse
# Saved followers for user: BrnMetaverse
# Fetching followers for user: soil_farm
# Saved followers for user: soil_farm
# Fetching followers for user: TensorplexLabs
# Saved followers for user: TensorplexLabs
# Fetching followers for user: ConvergenceFin
# Saved followers for user: ConvergenceFin
# Fetching followers for user: oraidex
# Error fetching followers for user oraidex: User is suspended. Retrying (1/3)...
# Error fetching followers for user oraidex: User is suspended. Retrying (2/3)...
# Error fetching followers for user oraidex: User is suspended. Retrying (3/3)...
# Error fetching followers for user oraidex: User is suspended. Retrying (4/3)...
# Fetching followers for user: SturdyFinance
# Saved followers for user: SturdyFinance
# Fetching followers for user: CryptoRubic
# Saved followers for user: CryptoRubic
# Fetching followers for user: ispolink
# Saved followers for user: ispolink
# Fetching followers for user: thorstarter
# Saved followers for user: thorstarter
# Fetching followers for user: OndoFinance
# Saved followers for user: OndoFinance
# Fetching followers for user: liquid_col
# Error fetching followers for user liquid_col: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user liquid_col: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: liquid_col
# Fetching followers for user: Vaultkaofficial
# Saved followers for user: Vaultkaofficial
# Fetching followers for user: CogitoProtocol
# Saved followers for user: CogitoProtocol
# Fetching followers for user: oddz_finance
# Saved followers for user: oddz_finance
# Fetching followers for user: GravityChain
# Saved followers for user: GravityChain
# Fetching followers for user: MountainUSDM
# Error fetching followers for user MountainUSDM: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user MountainUSDM: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: MountainUSDM
# Fetching followers for user: zero1_labs
# Saved followers for user: zero1_labs
# Fetching followers for user: Swisscheese_fn
# Saved followers for user: Swisscheese_fn
# Fetching followers for user: antfarmfinance
# Saved followers for user: antfarmfinance
# Fetching followers for user: Bedrock_DeFi
# Saved followers for user: Bedrock_DeFi
# Fetching followers for user: VelasPad
# Error fetching followers for user VelasPad: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user VelasPad: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: VelasPad
# Fetching followers for user: chirpley
# Saved followers for user: chirpley
# Fetching followers for user: Brickken
# Saved followers for user: Brickken
# Fetching followers for user: HeraAggregator
# Saved followers for user: HeraAggregator
# Fetching followers for user: galeoncare
# Saved followers for user: galeoncare
# Fetching followers for user: Givethio
# Error fetching followers for user Givethio: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Givethio: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Givethio
# Fetching followers for user: xpnetwork_
# Saved followers for user: xpnetwork_
# Fetching followers for user: TrustSwap
# Saved followers for user: TrustSwap
# Fetching followers for user: Cindicator
# Saved followers for user: Cindicator
# Fetching followers for user: UniswapProtocol
# Saved followers for user: UniswapProtocol
# Fetching followers for user: InterportFi
# Error fetching followers for user InterportFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user InterportFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: InterportFi
# Fetching followers for user: alephium
# Saved followers for user: alephium
# Fetching followers for user: LiskHQ
# Saved followers for user: LiskHQ
# Fetching followers for user: RenzoProtocol
# Saved followers for user: RenzoProtocol
# Fetching followers for user: PrismaFi
# Saved followers for user: PrismaFi
# Fetching followers for user: decentra_web
# Error fetching followers for user decentra_web: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user decentra_web: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: decentra_web
# Fetching followers for user: flooringproto_
# Error fetching followers for user flooringproto_: User is suspended. Retrying (1/3)...
# Error fetching followers for user flooringproto_: User is suspended. Retrying (2/3)...
# Error fetching followers for user flooringproto_: User is suspended. Retrying (3/3)...
# Error fetching followers for user flooringproto_: User is suspended. Retrying (4/3)...
# Fetching followers for user: StoboxCompany
# Saved followers for user: StoboxCompany
# Fetching followers for user: bigdataprotocol
# Saved followers for user: bigdataprotocol
# Fetching followers for user: TGCasino_
# Saved followers for user: TGCasino_
# Fetching followers for user: ErthaGame
# Saved followers for user: ErthaGame
# Fetching followers for user: SperaxUSD
# Saved followers for user: SperaxUSD
# Fetching followers for user: Chappyzcom
# Error fetching followers for user Chappyzcom: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Chappyzcom: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Chappyzcom
# Fetching followers for user: Range_Protocol
# Saved followers for user: Range_Protocol
# Fetching followers for user: VNX_Platform
# Saved followers for user: VNX_Platform
# Fetching followers for user: enter_realm
# Saved followers for user: enter_realm
# Fetching followers for user: myria
# Saved followers for user: myria
# Fetching followers for user: BaoCommunity
# Error fetching followers for user BaoCommunity: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user BaoCommunity: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: BaoCommunity
# Fetching followers for user: standardweb3
# Saved followers for user: standardweb3
# Fetching followers for user: LayerZero_Labs
# Saved followers for user: LayerZero_Labs
# Fetching followers for user: LayerZero_Labs
# Saved followers for user: LayerZero_Labs
# Fetching followers for user: DeriProtocol
# Saved followers for user: DeriProtocol
# Fetching followers for user: ritestream_io
# Error fetching followers for user ritestream_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ritestream_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ritestream_io
# Fetching followers for user: BetSwirl
# Saved followers for user: BetSwirl
# Fetching followers for user: EpochIsland
# Saved followers for user: EpochIsland
# Fetching followers for user: KelpDAO
# Saved followers for user: KelpDAO
# Fetching followers for user: OffshiftXFT
# Saved followers for user: OffshiftXFT
# Fetching followers for user: garden_finance
# Error fetching followers for user garden_finance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user garden_finance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: garden_finance
# Fetching followers for user: PlanqFoundation
# Saved followers for user: PlanqFoundation
# Fetching followers for user: Chainflip
# Saved followers for user: Chainflip
# Fetching followers for user: ProBit_Exchange
# Saved followers for user: ProBit_Exchange
# Fetching followers for user: asksensay
# Saved followers for user: asksensay
# Fetching followers for user: MintClubPro
# Error fetching followers for user MintClubPro: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user MintClubPro: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: MintClubPro
# Fetching followers for user: creo_engine
# Saved followers for user: creo_engine
# Fetching followers for user: ThetanutsFi
# Saved followers for user: ThetanutsFi
# Fetching followers for user: beefyfinance
# Saved followers for user: beefyfinance
# Fetching followers for user: OXFUNHQ
# Saved followers for user: OXFUNHQ
# Fetching followers for user: Allbridge_io
# Error fetching followers for user Allbridge_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Allbridge_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Allbridge_io
# Fetching followers for user: coldstack_io
# Saved followers for user: coldstack_io
# Fetching followers for user: slamtoken
# Saved followers for user: slamtoken
# Fetching followers for user: ajnafi
# Saved followers for user: ajnafi
# Fetching followers for user: dogami
# Saved followers for user: dogami
# Fetching followers for user: TheMahaDAO
# Error fetching followers for user TheMahaDAO: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user TheMahaDAO: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: TheMahaDAO
# Fetching followers for user: TheTNetwork
# Saved followers for user: TheTNetwork
# Fetching followers for user: onopenxyz
# Saved followers for user: onopenxyz
# Fetching followers for user: blockchainspc
# Saved followers for user: blockchainspc
# Fetching followers for user: ForwardProtocol
# Saved followers for user: ForwardProtocol
# Fetching followers for user: sirenprotocol
# Error fetching followers for user sirenprotocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user sirenprotocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: sirenprotocol
# Fetching followers for user: 4thecoin
# Saved followers for user: 4thecoin
# Fetching followers for user: projectquint
# Saved followers for user: projectquint
# Fetching followers for user: DefiPlaza
# Saved followers for user: DefiPlaza
# Fetching followers for user: Opium_Network
# Saved followers for user: Opium_Network
# Fetching followers for user: JulSwap
# Error fetching followers for user JulSwap: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user JulSwap: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: JulSwap
# Fetching followers for user: TopGoal_NFT
# Saved followers for user: TopGoal_NFT
# Fetching followers for user: neworderDAO
# Saved followers for user: neworderDAO
# Fetching followers for user: playWAM
# Saved followers for user: playWAM
# Fetching followers for user: DevPillar
# Saved followers for user: DevPillar
# Fetching followers for user: minu_coin
# Error fetching followers for user minu_coin: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user minu_coin: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: minu_coin
# Fetching followers for user: mong_coin
# Saved followers for user: mong_coin
# Fetching followers for user: bullperks
# Saved followers for user: bullperks
# Fetching followers for user: 0xPolygon
# Saved followers for user: 0xPolygon
# Fetching followers for user: velhallaproject
# Error fetching followers for user velhallaproject: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user velhallaproject: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user velhallaproject: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user velhallaproject: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: yup_io
# Saved followers for user: yup_io
# Fetching followers for user: Lympo_io
# Saved followers for user: Lympo_io
# Fetching followers for user: nizacoin
# Saved followers for user: nizacoin
# Fetching followers for user: Pandora_DEX
# Saved followers for user: Pandora_DEX
# Fetching followers for user: vectorreserve
# Saved followers for user: vectorreserve
# Fetching followers for user: zetablockchain
# Error fetching followers for user zetablockchain: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user zetablockchain: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: zetablockchain
# Fetching followers for user: ethena_labs
# Saved followers for user: ethena_labs
# Fetching followers for user: PrimeStaked
# Saved followers for user: PrimeStaked
# Fetching followers for user: dypius
# Saved followers for user: dypius
# Fetching followers for user: HordApp
# Saved followers for user: HordApp
# Fetching followers for user: Lifeformcc
# Error fetching followers for user Lifeformcc: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Lifeformcc: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Lifeformcc
# Fetching followers for user: arixdexofficial
# Saved followers for user: arixdexofficial
# Fetching followers for user: XAI_GAMES
# Saved followers for user: XAI_GAMES
# Fetching followers for user: naos_finance
# Saved followers for user: naos_finance
# Fetching followers for user: unvest_io
# Saved followers for user: unvest_io
# Fetching followers for user: TheBoringDAO
# Error fetching followers for user TheBoringDAO: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user TheBoringDAO: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: TheBoringDAO
# Fetching followers for user: TheTruBadger
# Saved followers for user: TheTruBadger
# Fetching followers for user: quadency
# Error fetching followers for user quadency: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user quadency: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user quadency: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user quadency: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: yel_finance
# Saved followers for user: yel_finance
# Fetching followers for user: saffronfinance_
# Saved followers for user: saffronfinance_
# Fetching followers for user: drunk_robots
# Saved followers for user: drunk_robots
# Fetching followers for user: PeapodsFinance
# Saved followers for user: PeapodsFinance
# Fetching followers for user: plxyerglobal
# Saved followers for user: plxyerglobal
# Fetching followers for user: ACTDeFansFi
# Error fetching followers for user ACTDeFansFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ACTDeFansFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ACTDeFansFi
# Fetching followers for user: fusionistio
# Saved followers for user: fusionistio
# Fetching followers for user: dexkit
# Saved followers for user: dexkit
# Fetching followers for user: vertex_protocol
# Saved followers for user: vertex_protocol
# Fetching followers for user: LiquidDriver
# Saved followers for user: LiquidDriver
# Fetching followers for user: tidaldefi
# Error fetching followers for user tidaldefi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user tidaldefi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: tidaldefi
# Fetching followers for user: themetajuice
# Saved followers for user: themetajuice
# Fetching followers for user: _alchemistcoin
# Saved followers for user: _alchemistcoin
# Fetching followers for user: cardstack
# Saved followers for user: cardstack
# Fetching followers for user: aipadtech
# Saved followers for user: aipadtech
# Fetching followers for user: ElandToken
# Error fetching followers for user ElandToken: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ElandToken: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ElandToken
# Fetching followers for user: Moby_trade
# Saved followers for user: Moby_trade
# Fetching followers for user: truflation
# Saved followers for user: truflation
# Fetching followers for user: oasisprotocol
# Saved followers for user: oasisprotocol
# Fetching followers for user: ShezmuTech
# Saved followers for user: ShezmuTech
# Fetching followers for user: Starknet
# Error fetching followers for user Starknet: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Starknet: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Starknet
# Fetching followers for user: taikoxyz
# Saved followers for user: taikoxyz
# Fetching followers for user: NolusProtocol
# Saved followers for user: NolusProtocol
# Fetching followers for user: eesee_io
# Saved followers for user: eesee_io
# Fetching followers for user: MOCAFoundation
# Saved followers for user: MOCAFoundation
# Fetching followers for user: Unfederalreser1
# Error fetching followers for user Unfederalreser1: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user Unfederalreser1: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user Unfederalreser1: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user Unfederalreser1: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: xendfinance
# Saved followers for user: xendfinance
# Fetching followers for user: BiFi_lending
# Saved followers for user: BiFi_lending
# Fetching followers for user: officialcrgpt
# Saved followers for user: officialcrgpt
# Fetching followers for user: 0xMantle
# Saved followers for user: 0xMantle
# Fetching followers for user: TruFinProtocol
# Saved followers for user: TruFinProtocol
# Fetching followers for user: Purefi_Protocol
# Error fetching followers for user Purefi_Protocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Purefi_Protocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Purefi_Protocol
# Fetching followers for user: TarotFinance
# Saved followers for user: TarotFinance
# Fetching followers for user: EdgewareDAO
# Saved followers for user: EdgewareDAO
# Fetching followers for user: RamsesExchange
# Saved followers for user: RamsesExchange
# Fetching followers for user: binance
# Saved followers for user: binance
# Fetching followers for user: Coinbase
# Error fetching followers for user Coinbase: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Coinbase: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Coinbase
# Fetching followers for user: kucoincom
# Saved followers for user: kucoincom
# Fetching followers for user: bitfinex
# Saved followers for user: bitfinex
# Fetching followers for user: cryptocom
# Saved followers for user: cryptocom
# Fetching followers for user: HuobiGlobal
# Saved followers for user: HuobiGlobal
# Fetching followers for user: Bybit_Official
# Error fetching followers for user Bybit_Official: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Bybit_Official: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Bybit_Official
# Fetching followers for user: gate_io
# Saved followers for user: gate_io
# Fetching followers for user: binanceUS
# Saved followers for user: binanceUS
# Fetching followers for user: OKX
# Saved followers for user: OKX
# Fetching followers for user: bitgetglobal
# Saved followers for user: bitgetglobal
# Fetching followers for user: krakenfx
# Error fetching followers for user krakenfx: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user krakenfx: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: krakenfx
# Fetching followers for user: Gemini
# Saved followers for user: Gemini
# Fetching followers for user: BitMartExchange
# Saved followers for user: BitMartExchange
# Fetching followers for user: latokens
# Saved followers for user: latokens
# Fetching followers for user: Official_Upbit
# Saved followers for user: Official_Upbit
# Fetching followers for user: BithumbOfficial
# Error fetching followers for user BithumbOfficial: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user BithumbOfficial: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: BithumbOfficial
# Fetching followers for user: Bitstamp
# Saved followers for user: Bitstamp
# Fetching followers for user: BitMEXdotcom
# Saved followers for user: BitMEXdotcom
# Fetching followers for user: Poloniex
# Saved followers for user: Poloniex
# Fetching followers for user: whitebit
# Saved followers for user: whitebit
# Fetching followers for user: digifinex
# Error fetching followers for user digifinex: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user digifinex: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: digifinex
# Fetching followers for user: coinexcom
# Saved followers for user: coinexcom
# Fetching followers for user: BigONEexchange
# Saved followers for user: BigONEexchange
# Fetching followers for user: bitFlyer
# Saved followers for user: bitFlyer
# Fetching followers for user: CoinoneOfficial
# Saved followers for user: CoinoneOfficial
# Fetching followers for user: BitrueOfficial
# Error fetching followers for user BitrueOfficial: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user BitrueOfficial: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: BitrueOfficial
# Fetching followers for user: XTexchange
# Saved followers for user: XTexchange
# Fetching followers for user: CoinWOfficial
# Saved followers for user: CoinWOfficial
# Fetching followers for user: Indoex_LTD
# Saved followers for user: Indoex_LTD
# Fetching followers for user: Phemex_official
# Saved followers for user: Phemex_official
# Fetching followers for user: Blastup_io
# Error fetching followers for user Blastup_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Blastup_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Blastup_io
# Fetching followers for user: w3w_exchange
# Saved followers for user: w3w_exchange
# Fetching followers for user: sacra_fi
# Saved followers for user: sacra_fi
# Fetching followers for user: emdx_io
# Saved followers for user: emdx_io
# Fetching followers for user: gudchain
# Saved followers for user: gudchain
# Fetching followers for user: synthswapio
# Error fetching followers for user synthswapio: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user synthswapio: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: synthswapio
# Fetching followers for user: trava_finance
# Saved followers for user: trava_finance
# Fetching followers for user: suilendprotocol
# Saved followers for user: suilendprotocol
# Fetching followers for user: metalegendsnft
# Saved followers for user: metalegendsnft
# Fetching followers for user: MMFcrypto
# Saved followers for user: MMFcrypto
# Fetching followers for user: UnslashedF
# Error fetching followers for user UnslashedF: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user UnslashedF: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: UnslashedF
# Fetching followers for user: MugenFinance
# Saved followers for user: MugenFinance
# Fetching followers for user: NeopinOfficial
# Saved followers for user: NeopinOfficial
# Fetching followers for user: EnterTheStrudel
# Saved followers for user: EnterTheStrudel
# Fetching followers for user: FactorDAO
# Error fetching followers for user FactorDAO: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user FactorDAO: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user FactorDAO: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user FactorDAO: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: izumi_Finance
# Saved followers for user: izumi_Finance
# Fetching followers for user: CreamdotFinance
# Saved followers for user: CreamdotFinance
# Fetching followers for user: Swapr_dapp
# Saved followers for user: Swapr_dapp
# Fetching followers for user: DotDotDotFi
# Saved followers for user: DotDotDotFi
# Fetching followers for user: ClayStack_HQ
# Saved followers for user: ClayStack_HQ
# Fetching followers for user: ndxfi
# Error fetching followers for user ndxfi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ndxfi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ndxfi
# Fetching followers for user: dsumoney
# Saved followers for user: dsumoney
# Fetching followers for user: MorphexFTM
# Saved followers for user: MorphexFTM
# Fetching followers for user: TheIdolsNFT
# Saved followers for user: TheIdolsNFT
# Fetching followers for user: cycloneprotocol
# Saved followers for user: cycloneprotocol
# Fetching followers for user: IntegralHQ
# Error fetching followers for user IntegralHQ: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user IntegralHQ: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: IntegralHQ
# Fetching followers for user: vela_exchange
# Saved followers for user: vela_exchange
# Fetching followers for user: EmpMoneyBSC
# Saved followers for user: EmpMoneyBSC
# Fetching followers for user: CamelotDEX
# Saved followers for user: CamelotDEX
# Fetching followers for user: dForcenet
# Saved followers for user: dForcenet
# Fetching followers for user: JPEGd_69
# Error fetching followers for user JPEGd_69: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user JPEGd_69: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: JPEGd_69
# Fetching followers for user: PieDAO_Defi
# Saved followers for user: PieDAO_Defi
# Fetching followers for user: aurigami_PLY
# Saved followers for user: aurigami_PLY
# Fetching followers for user: MetronomeDAO
# Saved followers for user: MetronomeDAO
# Fetching followers for user: KnightEcosystem
# Saved followers for user: KnightEcosystem
# Fetching followers for user: LodestarFinance
# Error fetching followers for user LodestarFinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user LodestarFinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: LodestarFinance
# Fetching followers for user: UmamiDao
# Saved followers for user: UmamiDao
# Fetching followers for user: PancakeBunnyFin
# Saved followers for user: PancakeBunnyFin
# Fetching followers for user: ImpermaxFinance
# Saved followers for user: ImpermaxFinance
# Fetching followers for user: phuture_finance
# Saved followers for user: phuture_finance
# Fetching followers for user: Meshswap_Fi
# Error fetching followers for user Meshswap_Fi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Meshswap_Fi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Meshswap_Fi
# Fetching followers for user: BTC_proxy
# Saved followers for user: BTC_proxy
# Fetching followers for user: babyswap_bsc
# Saved followers for user: babyswap_bsc
# Fetching followers for user: acryptosdao
# Saved followers for user: acryptosdao
# Fetching followers for user: WINRProtocol
# Saved followers for user: WINRProtocol
# Fetching followers for user: archi_fi
# Error fetching followers for user archi_fi: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user archi_fi: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user archi_fi: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user archi_fi: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: asymmetryfin
# Saved followers for user: asymmetryfin
# Fetching followers for user: xwinfinance
# Saved followers for user: xwinfinance
# Fetching followers for user: D2_Finance
# Saved followers for user: D2_Finance
# Fetching followers for user: goatfidao
# Saved followers for user: goatfidao
# Fetching followers for user: unitusfi
# Saved followers for user: unitusfi
# Fetching followers for user: SushiSwap
# Error fetching followers for user SushiSwap: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user SushiSwap: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: SushiSwap
# Fetching followers for user: PlutusDAO_io
# Saved followers for user: PlutusDAO_io
# Fetching followers for user: CCB_Bridge
# Saved followers for user: CCB_Bridge
# Fetching followers for user: aktionariat
# Saved followers for user: aktionariat
# Fetching followers for user: DeltaPrimeDefi
# Saved followers for user: DeltaPrimeDefi
# Fetching followers for user: GuardaWallet
# Error fetching followers for user GuardaWallet: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user GuardaWallet: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: GuardaWallet
# Fetching followers for user: xtokenterminal
# Saved followers for user: xtokenterminal
# Fetching followers for user: universe_xyz
# Saved followers for user: universe_xyz
# Fetching followers for user: MoonfarmFinance
# Saved followers for user: MoonfarmFinance
# Fetching followers for user: rook
# Saved followers for user: rook
# Fetching followers for user: imMoonSwap
# Error fetching followers for user imMoonSwap: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user imMoonSwap: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: imMoonSwap
# Fetching followers for user: revaultnetwork
# Error fetching followers for user revaultnetwork: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user revaultnetwork: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user revaultnetwork: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user revaultnetwork: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: chain_port
# Saved followers for user: chain_port
# Fetching followers for user: ApeBond
# Saved followers for user: ApeBond
# Fetching followers for user: tangibleDAO
# Saved followers for user: tangibleDAO
# Fetching followers for user: tranchess
# Saved followers for user: tranchess
# Fetching followers for user: defidollar
# Saved followers for user: defidollar
# Fetching followers for user: CurveFinance
# Error fetching followers for user CurveFinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user CurveFinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: CurveFinance
# Fetching followers for user: BlastFutures
# Saved followers for user: BlastFutures
# Fetching followers for user: gnosischain
# Saved followers for user: gnosischain
# Fetching followers for user: PearlFi_
# Saved followers for user: PearlFi_
# Fetching followers for user: stusdtio
# Saved followers for user: stusdtio
# Fetching followers for user: DexFinance
# Error fetching followers for user DexFinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user DexFinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: DexFinance
# Fetching followers for user: Spartadex_io
# Saved followers for user: Spartadex_io
# Fetching followers for user: KinetixFi
# Saved followers for user: KinetixFi
# Fetching followers for user: Liquisfi
# Saved followers for user: Liquisfi
# Fetching followers for user: divastaking
# Saved followers for user: divastaking
# Fetching followers for user: frankencoinzchf
# Error fetching followers for user frankencoinzchf: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user frankencoinzchf: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: frankencoinzchf
# Fetching followers for user: APX_Finance
# Saved followers for user: APX_Finance
# Fetching followers for user: 0xMantle
# Saved followers for user: 0xMantle
# Fetching followers for user: Lumi_Finance
# Saved followers for user: Lumi_Finance
# Fetching followers for user: squad_swap
# Saved followers for user: squad_swap
# Fetching followers for user: segment_fi
# Error fetching followers for user segment_fi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user segment_fi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: segment_fi
# Fetching followers for user: synonymfinance
# Saved followers for user: synonymfinance
# Fetching followers for user: synonymfinance
# Saved followers for user: synonymfinance
# Fetching followers for user: MorpheusAIs
# Saved followers for user: MorpheusAIs
# Fetching followers for user: reserveprotocol
# Saved followers for user: reserveprotocol
# Fetching followers for user: Immutable
# Saved followers for user: Immutable
# Fetching followers for user: BlackRock
# Error fetching followers for user BlackRock: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user BlackRock: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: BlackRock
# Fetching followers for user: AurusOfficial
# Saved followers for user: AurusOfficial
# Fetching followers for user: Arcade_xyz
# Saved followers for user: Arcade_xyz
# Fetching followers for user: Orbit_Chain
# Saved followers for user: Orbit_Chain
# Fetching followers for user: meta_pool
# Saved followers for user: meta_pool
# Fetching followers for user: jojo_exchange
# Error fetching followers for user jojo_exchange: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user jojo_exchange: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: jojo_exchange
# Fetching followers for user: Honeyswap
# Saved followers for user: Honeyswap
# Fetching followers for user: DepthFi
# Saved followers for user: DepthFi
# Fetching followers for user: binance
# Saved followers for user: binance
# Fetching followers for user: Hope_money_
# Saved followers for user: Hope_money_
# Fetching followers for user: 0xDYAD
# Error fetching followers for user 0xDYAD: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user 0xDYAD: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: 0xDYAD
# Fetching followers for user: Stake_Stone
# Saved followers for user: Stake_Stone
# Fetching followers for user: BTCB2B
# Saved followers for user: BTCB2B
# Fetching followers for user: 0xfluid
# Saved followers for user: 0xfluid
# Fetching followers for user: airpuff_io
# Saved followers for user: airpuff_io
# Fetching followers for user: airpuff_io
# Saved followers for user: airpuff_io
# Fetching followers for user: yieldnestFi
# Error fetching followers for user yieldnestFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user yieldnestFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: yieldnestFi
# Fetching followers for user: loopfixyz
# Saved followers for user: loopfixyz
# Fetching followers for user: KernelProtocol
# Saved followers for user: KernelProtocol
# Fetching followers for user: usualmoney
# Saved followers for user: usualmoney
# Fetching followers for user: Convergence_fi
# Saved followers for user: Convergence_fi
# Fetching followers for user: paraluni
# Error fetching followers for user paraluni: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user paraluni: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: paraluni
# Fetching followers for user: ToucanProtocol
# Saved followers for user: ToucanProtocol
# Fetching followers for user: iotube_org
# Saved followers for user: iotube_org
# Fetching followers for user: flamincome
# Saved followers for user: flamincome
# Fetching followers for user: OuchiFinance
# Error fetching followers for user OuchiFinance: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user OuchiFinance: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user OuchiFinance: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user OuchiFinance: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: Sherlock_DeFi
# Saved followers for user: Sherlock_DeFi
# Fetching followers for user: deBridgeFinance
# Saved followers for user: deBridgeFinance
# Fetching followers for user: Node_DAO
# Saved followers for user: Node_DAO
# Fetching followers for user: BloctoApp
# Saved followers for user: BloctoApp
# Fetching followers for user: Aark_Digital
# Saved followers for user: Aark_Digital
# Fetching followers for user: Arch_Finance
# Error fetching followers for user Arch_Finance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Arch_Finance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Arch_Finance
# Fetching followers for user: yieldflowdotcom
# Saved followers for user: yieldflowdotcom
# Fetching followers for user: Amphor_io
# Saved followers for user: Amphor_io
# Fetching followers for user: Hashnote_Labs
# Saved followers for user: Hashnote_Labs
# Fetching followers for user: Hashnote_Labs
# Saved followers for user: Hashnote_Labs
# Fetching followers for user: d8x_exchange
# Error fetching followers for user d8x_exchange: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user d8x_exchange: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: d8x_exchange
# Fetching followers for user: kumaprotocol
# Saved followers for user: kumaprotocol
# Fetching followers for user: InceptionLRT
# Saved followers for user: InceptionLRT
# Fetching followers for user: aspidanet
# Saved followers for user: aspidanet
# Fetching followers for user: bounce_bit
# Saved followers for user: bounce_bit
# Fetching followers for user: DinariGlobal
# Error fetching followers for user DinariGlobal: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user DinariGlobal: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: DinariGlobal
# Fetching followers for user: ZircuitL2
# Saved followers for user: ZircuitL2
# Fetching followers for user: superstatefunds
# Saved followers for user: superstatefunds
# Fetching followers for user: AmpleforthOrg
# Saved followers for user: AmpleforthOrg
# Fetching followers for user: zkLink_Official
# Saved followers for user: zkLink_Official
# Fetching followers for user: HakkaFinance
# Error fetching followers for user HakkaFinance: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user HakkaFinance: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: HakkaFinance
# Fetching followers for user: YieldWars
# Saved followers for user: YieldWars
# Fetching followers for user: PoWH3D
# Saved followers for user: PoWH3D
# Fetching followers for user: BitU_Protocol
# Saved followers for user: BitU_Protocol
# Fetching followers for user: ResolvLabs
# Saved followers for user: ResolvLabs
# Fetching followers for user: ArrakisFinance
# Saved followers for user: ArrakisFinance
# Fetching followers for user: llamapay_io
# Error fetching followers for user llamapay_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user llamapay_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: llamapay_io
# Fetching followers for user: perenniallabs
# Saved followers for user: perenniallabs
# Fetching followers for user: PodsFinance
# Saved followers for user: PodsFinance
# Fetching followers for user: PolyNetwork2
# Saved followers for user: PolyNetwork2
# Fetching followers for user: PolymarketHQ
# Saved followers for user: PolymarketHQ
# Fetching followers for user: ButterNetworkio
# Error fetching followers for user ButterNetworkio: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user ButterNetworkio: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: ButterNetworkio
# Fetching followers for user: mellowprotocol
# Saved followers for user: mellowprotocol
# Fetching followers for user: SetProtocol
# Saved followers for user: SetProtocol
# Fetching followers for user: Contango_xyz
# Saved followers for user: Contango_xyz
# Fetching followers for user: cryptopepeteam
# Saved followers for user: cryptopepeteam
# Fetching followers for user: wanchain_org
# Error fetching followers for user wanchain_org: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user wanchain_org: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: wanchain_org
# Fetching followers for user: native_fi
# Saved followers for user: native_fi
# Fetching followers for user: Superfluid_HQ
# Saved followers for user: Superfluid_HQ
# Fetching followers for user: aztecnetwork
# Saved followers for user: aztecnetwork
# Fetching followers for user: GyroStable
# Saved followers for user: GyroStable
# Fetching followers for user: Dolomite_io
# Error fetching followers for user Dolomite_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Dolomite_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Dolomite_io
# Fetching followers for user: CharmFinance
# Saved followers for user: CharmFinance
# Fetching followers for user: cozyfinance
# Saved followers for user: cozyfinance
# Fetching followers for user: DefiSaver
# Saved followers for user: DefiSaver
# Fetching followers for user: metastreetxyz
# Saved followers for user: metastreetxyz
# Fetching followers for user: CIAN_protocol
# Error fetching followers for user CIAN_protocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user CIAN_protocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: CIAN_protocol
# Fetching followers for user: SablierHQ
# Saved followers for user: SablierHQ
# Fetching followers for user: wasabi_protocol
# Saved followers for user: wasabi_protocol
# Fetching followers for user: steadefi
# Error fetching followers for user steadefi: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user steadefi: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user steadefi: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user steadefi: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: carbondefixyz
# Saved followers for user: carbondefixyz
# Fetching followers for user: OpenEden_Labs
# Saved followers for user: OpenEden_Labs
# Fetching followers for user: ambient_finance
# Saved followers for user: ambient_finance
# Fetching followers for user: ResonateFi
# Saved followers for user: ResonateFi
# Fetching followers for user: kinzafinance
# Saved followers for user: kinzafinance
# Fetching followers for user: GammaSwapLabs
# Error fetching followers for user GammaSwapLabs: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user GammaSwapLabs: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: GammaSwapLabs
# Fetching followers for user: ButtonDeFi
# Saved followers for user: ButtonDeFi
# Fetching followers for user: gondixyz
# Saved followers for user: gondixyz
# Fetching followers for user: LOCKONfinance
# Saved followers for user: LOCKONfinance
# Fetching followers for user: _Fortunafi
# Saved followers for user: _Fortunafi
# Fetching followers for user: Allbridge_io
# Error fetching followers for user Allbridge_io: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Allbridge_io: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Allbridge_io
# Fetching followers for user: DesynLab
# Saved followers for user: DesynLab
# Fetching followers for user: ButterSwapio
# Error fetching followers for user ButterSwapio: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user ButterSwapio: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user ButterSwapio: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user ButterSwapio: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: blueberryFDN
# Saved followers for user: blueberryFDN
# Fetching followers for user: puffer_finance
# Saved followers for user: puffer_finance
# Fetching followers for user: buildwithsygma
# Saved followers for user: buildwithsygma
# Fetching followers for user: buildwithsygma
# Saved followers for user: buildwithsygma
# Fetching followers for user: ambitfinance
# Saved followers for user: ambitfinance
# Fetching followers for user: ambitfinance
# Saved followers for user: ambitfinance
# Fetching followers for user: CopraFi
# Error fetching followers for user CopraFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user CopraFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: CopraFi
# Fetching followers for user: build_on_bob
# Saved followers for user: build_on_bob
# Fetching followers for user: BurveProtocol
# Saved followers for user: BurveProtocol
# Fetching followers for user: blackwing_fi
# Saved followers for user: blackwing_fi
# Fetching followers for user: superformxyz
# Saved followers for user: superformxyz
# Fetching followers for user: hinkal_protocol
# Error fetching followers for user hinkal_protocol: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user hinkal_protocol: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: hinkal_protocol
# Fetching followers for user: eBTCprotocol
# Saved followers for user: eBTCprotocol
# Fetching followers for user: ionprotocol
# Saved followers for user: ionprotocol
# Fetching followers for user: aloecapital
# Saved followers for user: aloecapital
# Fetching followers for user: jaspervault
# Saved followers for user: jaspervault
# Fetching followers for user: symbioticfi
# Error fetching followers for user symbioticfi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user symbioticfi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: symbioticfi
# Fetching followers for user: XLinkbtc
# Saved followers for user: XLinkbtc
# Fetching followers for user: RIZE_Fi
# Error fetching followers for user RIZE_Fi: The User Account wasn't Found or is Protected. Retrying (1/3)...
# Error fetching followers for user RIZE_Fi: The User Account wasn't Found or is Protected. Retrying (2/3)...
# Error fetching followers for user RIZE_Fi: The User Account wasn't Found or is Protected. Retrying (3/3)...
# Error fetching followers for user RIZE_Fi: The User Account wasn't Found or is Protected. Retrying (4/3)...
# Fetching followers for user: NapierFinance
# Saved followers for user: NapierFinance
# Fetching followers for user: AstherusHub
# Saved followers for user: AstherusHub
# Fetching followers for user: mindnetwork_xyz
# Saved followers for user: mindnetwork_xyz
# Fetching followers for user: MidasRWA
# Saved followers for user: MidasRWA
# Fetching followers for user: TegroDEX
# Saved followers for user: TegroDEX
# Fetching followers for user: Megaton_Fi
# Error fetching followers for user Megaton_Fi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user Megaton_Fi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: Megaton_Fi
# Fetching followers for user: ston_fi
# Saved followers for user: ston_fi
# Fetching followers for user: dedust_io
# Saved followers for user: dedust_io
# Fetching followers for user: daolama_ton
# Saved followers for user: daolama_ton
# Fetching followers for user: bemo_finance
# Saved followers for user: bemo_finance
# Fetching followers for user: bemo_finance
# Saved followers for user: bemo_finance
# Fetching followers for user: tonstakers
# Error fetching followers for user tonstakers: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user tonstakers: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: tonstakers
# Fetching followers for user: Cock_Fights
# Saved followers for user: Cock_Fights
# Fetching followers for user: hipofinance
# Saved followers for user: hipofinance
# Fetching followers for user: storm_trade_ton
# Saved followers for user: storm_trade_ton
# Fetching followers for user: evaaprotocol
# Saved followers for user: evaaprotocol
# Fetching followers for user: CygnusFi
# Error fetching followers for user CygnusFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user CygnusFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: CygnusFi
# Fetching followers for user: tonnel_network
# Saved followers for user: tonnel_network
# Fetching followers for user: TonsOfFriends
# Saved followers for user: TonsOfFriends
# Fetching followers for user: tradoor_io
# Saved followers for user: tradoor_io
# Fetching followers for user: Bridgersxyz
# Saved followers for user: Bridgersxyz
# Fetching followers for user: wontondotfun
# Error fetching followers for user wontondotfun: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user wontondotfun: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: wontondotfun
# Fetching followers for user: tonhedge
# Saved followers for user: tonhedge
# Fetching followers for user: balus_official
# Error fetching followers for user balus_official: User is suspended. Retrying (1/3)...
# Error fetching followers for user balus_official: User is suspended. Retrying (2/3)...
# Error fetching followers for user balus_official: User is suspended. Retrying (3/3)...
# Error fetching followers for user balus_official: User is suspended. Retrying (4/3)...
# Fetching followers for user: JVault_app
# Saved followers for user: JVault_app
# Fetching followers for user: TonSettle
# Saved followers for user: TonSettle
# Fetching followers for user: gaspump_tv
# Saved followers for user: gaspump_tv
# Fetching followers for user: TorchTon
# Saved followers for user: TorchTon
# Fetching followers for user: MuggleLink
# Saved followers for user: MuggleLink
# Fetching followers for user: TonStable
# Error fetching followers for user TonStable: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user TonStable: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: TonStable
# Fetching followers for user: parraton_com
# Saved followers for user: parraton_com
# Fetching followers for user: TonPools_Com
# Saved followers for user: TonPools_Com
# Fetching followers for user: pixelswap_io
# Saved followers for user: pixelswap_io
# Fetching followers for user: forge_game_bot
# Saved followers for user: forge_game_bot
# Fetching followers for user: handle_fi
# Error fetching followers for user handle_fi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user handle_fi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: handle_fi
# Fetching followers for user: WemixNetwork
# Saved followers for user: WemixNetwork
# Fetching followers for user: stakedotlink
# Saved followers for user: stakedotlink
# Fetching followers for user: yearnfi
# Saved followers for user: yearnfi
# Fetching followers for user: BendDAO
# Saved followers for user: BendDAO
# Fetching followers for user: TectonicFi
# Error fetching followers for user TectonicFi: [88] Rate limit exceeded
# . Retrying (1/3)...
# Error fetching followers for user TectonicFi: [88] Rate limit exceeded
# . Retrying (2/3)...
# Saved followers for user: TectonicFi
# Fetching followers for user: THORChain
# Saved followers for user: THORChain
